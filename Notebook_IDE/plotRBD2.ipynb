# %%
import matplotlib.pyplot as plt
import numpy as np
from math import exp

def draw(y1,y2):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    plt.plot(t,y1, 'b')
    plt.plot(t,y2, 'r')

    # show the plot
    plt.show()
    
t = np.linspace(0,3000)
y1 = np.exp(-0.00211*t) + np.exp(-0.00125*t) - np.exp(-0.00336*t)
y2 = np.exp(-0.00211*t) + np.exp(-0.001253*t) - np.exp(-0.002253*t)
draw(y1,y2)

t = np.linspace(0,3000)
y1 = np.exp(-0.00125*t) + np.exp(-0.00222*t) - np.exp(-0.00236*t)
y2 = np.exp(-0.00111*t) 
draw(y1,y2)

t = np.linspace(0,3000)
y1 = np.exp(-0.00139*t) + np.exp(-0.00236*t) - np.exp(-0.00250*t)
y2 = np.exp(-0.00125*t) 
draw(y1,y2)

t = np.linspace(0,3000)
y1 = np.exp(-0.00111*t) + np.exp(-0.00125*t) - np.exp(-0.00236*t)
y2 = np.exp(-0.00111*t) 
draw(y1,y2)
